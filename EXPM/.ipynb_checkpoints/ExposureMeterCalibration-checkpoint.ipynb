# %% [markdown]
# # Calibration of the CHIRON Exposure Meter

# %% [markdown]
# Here we determine the relation between the exposure meter counts and the SNR per pixel at the blaze peak nearest @ 5500 Å.

# %%
# %pylab inline
plt.rcParams['figure.figsize'] = 16, 12  # that's default image size for this interactive session
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from scipy.io.idl import readsav
import pylab as pl
import numpy as np
import os

# %% [markdown]
# ### Load the subroutines

# %%
def mattdir():
	if os.path.exists('/Users/mattgiguere/'):
		mdir = '/Users/mattgiguere/'
	elif os.path.exists('/Users/matt/'):
		mdir = '/Users/matt/'
	elif os.path.exists('/home/matt/'):
		mdir = '/home/matt/'
	else:
		mdir = ''
	print "mdir is: "+mdir
	return mdir

# %%
def plot_em(emcts, snr, order, mdir, star, model):
    simsize = 3
    #clear the window
    pl.clf()
    #set the x-axis
    pl.xlabel('EM Counts / 10^6')
    pl.ylabel('SNR')
    pl.plot(emcts/1e6, snr, 'bo', markersize=simsize)
    print "max snr: "+str(max(snr))
    pl.plot(emcts/1e6, model, 'ro', markersize=simsize)
    stddev = np.std(snr - model)
    print "Standard Deviation: "+str(stddev)
    pl.text(.55*max(emcts)/1e6, 0.375*max(snr), 'Polynomial Order: '+str(order))
    pl.text(.55*max(emcts)/1e6, 0.325*max(snr), 'Standard Deviation: {:.3}'.format(stddev))
    pl.text(.55*max(emcts)/1e6, 0.425*max(snr),'Star:'+str(order))
    #pl.show()
    pl.savefig(mdir+'projects/OTHER/NOTES/EXPM/em_cts_snr/'+star+'_emcts_snr_ord'+str(order)+'.eps')

# %%
def plot_airmass(snr, model, airmass, order, star):
    gdam = np.where(airmass != 0)[0]
    resids = np.zeros(len(gdam))
    airmgd = np.zeros(len(gdam))
    for i in range(len(gdam)):
        resids[i] = snr[gdam[i]] - model[gdam[i]]
        airmgd[i] = airmass[gdam[i]]
    pl.clf()
    pl.xlabel('Airmass')
    pl.ylabel('SNR - Model')
    pl.plot(airmgd, resids, 'ro')
    #pl.show()
    pl.savefig(mdir+'projects/OTHER/NOTES/EXPM/em_airmass/'+star+'_emcts_snr_ord'+str(order)+'.eps')

# %%
def get_starlog(star, mdir):
    """PURPOSE: To return the starlog"""
    slogfn = mdir+'data/CHIRPS/starlogs/'+star+'log.dat'
    sl = readsav(slogfn)
    return sl

# %%
def em_calib(star, mdir):
    slogfn = mdir+'data/CHIRPS/starlogs/'+star+'log.dat'
    sl = readsav(slogfn)
    #to print the contents of the "OBJECT" tag:
    #sl.starlog.object
    snrall = sl.starlog.snrbp5500
    emavgstr = sl.starlog.emavg
    emnumsmpstr = sl.starlog.emnumsmp
    airmassall = sl.starlog.airmass
    #now use only the good ones, the values with velocities:
    gd = np.where(sl.starlog.cmnvel != 0)[0]
    #print gd
    snr = np.zeros(len(gd))
    emavg = np.zeros(len(gd))
    emnumsmp = np.zeros(len(gd))
    airmass = np.zeros(len(gd))
    #print len(gd)
    for i in range(len(gd)):
        #print i, airmassall[gd[i]]
        snr[i] = float(snrall[gd[i]])
        emavg[i] = float(emavgstr[gd[i]])
        emnumsmp[i] = float(emnumsmpstr[gd[i]])
        if str(airmassall[gd[i]]).strip() != 'airmass' and str(airmassall[gd[i]]).strip() != '':
            airmass[i] = float(airmassall[gd[i]])
    emcts = emavg * emnumsmp
    return emcts, snr, airmass

# %% [markdown]
# ### Main body

# %%
#Figure out what computer you're on:
mdir = mattdir()
# Out:
# mdir is: /home/matt/

# %%
#The polynomial fit for the SNR(emcts). The counts should go as the square of the SNR:
order = 2

# %% [markdown]
# ### HD 20794

# %%
#The star you want to plot:
star = '20794'

# %%
emcts20794, snr20794, airmass20794 = em_calib(star, mdir)
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/scipy/io/idl.py:167: UserWarning: warning: empty strings are now set to '' instead of None
#   warnings.warn("warning: empty strings are now set to '' instead of None")
# /Applications/anaconda/lib/python2.7/site-packages/scipy/io/idl.py:180: UserWarning: warning: empty strings are now set to '' instead of None
#   warnings.warn("warning: empty strings are now set to '' instead of None")

# %%
model20794 = model_em(emcts20794, snr20794, order)
# Out:
# [ -5.30844981e-12   7.15585132e-05   6.42565213e+01]

# %%
plot_em(emcts20794, snr20794, order, mdir, star, model20794)
# Out:
# max snr: 309.293972565
# Standard Deviation: 5.40894628987

# %%
model20794_ord3 = model_em(emcts20794, snr20794, 3)
# Out:
# [  1.46986525e-18  -1.76717467e-11   1.00768890e-04   4.71494914e+01]

# %%
plot_em(emcts20794, snr20794, 3, mdir, star, model20794_ord3)
# Out:
# max snr: 309.293972565
# Standard Deviation: 4.13316457632

# %%
model20794_ord4 = model_em(emcts20794, snr20794, 4)
# Out:
# [ -4.28282359e-25   6.31331580e-18  -3.59116861e-11   1.26543625e-04
#    3.66953896e+01]

# %%
plot_em(emcts20794, snr20794, 4, mdir, star, model20794_ord4)
# Out:
# max snr: 309.293972565
# Standard Deviation: 3.88679583581

# %% [markdown]
# The second order model should fit the data very well. After all, the SNR is just the square root of the number of counts at blaze peak at 5500 $A$. However, a fourth-order model mysteriously fits the data much better than the second-order model, indicating a non-linearity between CCD counts and exposure meter PMT counts.

# %% [markdown]
# ### HD 10700

# %%
emcts10700, snr10700, airmass10700 = em_calib('10700', mdir)

# %%
model10700 = model_em(emcts10700, snr10700, order)
# Out:
# [ -2.38804258e-12   5.47173661e-05   8.31870625e+01]

# %%
plot_em(emcts10700, snr10700, order, mdir, star, model10700)
# Out:
# max snr: 396.13197921
# Standard Deviation: 8.22963766256

# %%
model10700_ord3 = model_em(emcts10700, snr10700, 3)
# Out:
# [  4.14125094e-19  -8.00326714e-12   7.60118630e-05   6.23514414e+01]

# %%
plot_em(emcts10700, snr10700, 3, mdir, star, model10700_ord3)
# Out:
# max snr: 396.13197921
# Standard Deviation: 7.36733546541

# %%
model10700_ord4 = model_em(emcts10700, snr10700, 4)
# Out:
# [ -4.23840429e-26   1.16674543e-18  -1.24290580e-11   8.56825228e-05
#    5.62399852e+01]

# %%
plot_em(emcts10700, snr10700, 4, mdir, star, model10700_ord4)
# Out:
# max snr: 396.13197921
# Standard Deviation: 7.33895808179

# %% [markdown]
# ### HD 22049

# %%
star='22049'
emcts22049, snr22049, airmass22049 = em_calib(star, mdir)

# %%
model22049_ord2 = model_em(emcts22049, snr22049, 2)
# Out:
# [ -8.27657529e-12   8.23329827e-05   5.86187090e+01]

# %%
plot_em(emcts22049, snr22049, 2, mdir, star, model22049_ord2)
# Out:
# max snr: 254.173979877
# Standard Deviation: 3.97982175941

# %%
model22049_ord4 = model_em(emcts22049, snr22049, 4)
plot_em(emcts22049, snr22049, 4, mdir, star, model22049_ord4)
# Out:
# [ -1.81513123e-24   1.74585768e-17  -6.46115893e-11   1.51798861e-04
#    3.31620857e+01]
# max snr: 254.173979877
# Standard Deviation: 3.18815608106

# %% [markdown]
# Just to show that there is negligible benefit in increasing the polynomial order beyond 4, I will create a 6th order polynomial model to fit the data:

# %%
model22049_ord6 = model_em(emcts22049, snr22049, 6)
plot_em(emcts22049, snr22049, 6, mdir, star, model22049_ord6)
# Out:
# [ -8.22461868e-37   9.28113886e-30  -4.23558495e-23   1.03572775e-16
#   -1.55962317e-10   1.95900128e-04   2.60281833e+01]
# max snr: 254.173979877
# Standard Deviation: 3.17177649734

# %% [markdown]
# ### HR 472

# %% [markdown]
# To increase the $B-V$ range, I will also include a B star in the calibration. HR 472 is the most observed B star with CHIRON.

# %%
def model_em(emcts, snr, ord):
    emcts /= np.max(emcts)
    snr /= np.max(snr)
    z = np.polyfit(emcts, snr, ord)
    print z
    mod = np.zeros(len(emcts))
    for i in range(ord+1):
        mod = mod + z[ord - i] * emcts**i
    return mod*np.max(emcts)

# %%
star='HR472'
sl472 = get_starlog(star, mdir)
#emctsHR472, snrHR472, airmassHR472 = em_calib(star, mdir)

# %%
snrHR472 = np.double(sl472.starlog.snrbp5500)
emavgstrHR472 = np.double(sl472.starlog.emavg)
emnumsmpstrHR472 = np.double(sl472.starlog.emnumsmp)
emctsHR472 = emavgstr472 * emnumsmpstr472
airmassHR472 = sl472.starlog.airmass
gds = np.where((snrHR472 > 0) & (emctsHR472 < 2e6) & (sl472.starlog.decker == 'slit    '))[0]

snrHR472 = snrHR472[gds]
emctsHR472 = emctsHR472[gds]
airmassHR472 = airmassHR472[gds]

# %%
print(len(emctsHR472))
print(len(emcts10700))
#print(len(gds[0]))
print(gds.size)
# Out:
# 91
# 1105
# 91

# %%
modelHR472_ord2 = model_em(emctsHR472, snrHR472, 2)
# Out:
# [ 0.57601032 -0.37191663  0.33465661]

# %%
plot_em(emctsHR472, snrHR472, 2, mdir, star, modelHR472_ord2)
# Out:
# max snr: 1.0
# Standard Deviation: 0.161572089775

# %%
modelHR472_ord4 = model_em(emctsHR472, snrHR472, 4)
# Out:
# [ 11.72249006 -25.76919263  18.49795508  -4.33068922   0.41706121]

# %%
plot_em(emctsHR472, snrHR472, 4, mdir, star, modelHR472_ord4)
# Out:
# max snr: 1.0
# Standard Deviation: 0.137274841383
